# %%
import pandas as pd
import numpy as np

#I installed tensorflow for CPU via Anaconda prompt.
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.compose import ColumnTransformer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

expectancy = pd.read_csv("life expectancy.csv")
expectancy.head()
expectancy.info()
expectancy.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Adult Mortality                  2938 non-null   float64
#  4   infant deaths                    2938 non-null   int64
#  5   Alcohol                          2938 non-null   float64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2938 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9    BMI                             2938 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2938 non-null   float64
#  12  Total expenditure                2938 non-null   float64
#  13  Diphtheria                       2938 non-null   float64
#  14   HIV/AIDS                        2938 non-null   float64
#  15  GDP                              2938 non-null   float64
#  16  Population                       2938 non-null   float64
#  17   thinness  1-19 years            2938 non-null   float64
#  18   thinness 5-9 years              2938 non-null   float64
#  19  Income composition of resources  2938 non-null   float64
#  20  Schooling                        2938 non-null   float64
#  21  Life expectancy                  2938 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB
#               Year  Adult Mortality  infant deaths      Alcohol  \
# count  2938.000000      2938.000000    2938.000000  2938.000000
# mean   2007.518720       164.725664      30.303948     4.546875
# std       4.613841       124.086215     117.926501     3.921946
# min    2000.000000         1.000000       0.000000     0.010000
# 25%    2004.000000        74.000000       0.000000     1.092500
# 50%    2008.000000       144.000000       3.000000     3.755000
# 75%    2012.000000       227.000000      22.000000     7.390000
# max    2015.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             2938.000000  2938.000000    2938.000000  2938.000000
# mean               738.251295    83.022124    2419.592240    38.381178
# std               1987.914858    22.996984   11467.272489    19.935375
# min                  0.000000     1.000000       0.000000     1.000000
# 25%                  4.685343    82.000000       0.000000    19.400000
# 50%                 64.912906    92.000000      17.000000    43.500000
# 75%                441.534144    96.000000     360.250000    56.100000
# max              19479.911610    99.000000  212183.000000    87.300000
#
#        under-five deaths         Polio  Total expenditure  Diphtheria   \
# count         2938.000000  2938.000000        2938.000000  2938.000000
# mean            42.035739    82.617767           5.924098    82.393125
# std            160.445548    23.367166           2.400770    23.655562
# min              0.000000     3.000000           0.370000     2.000000
# 25%              0.000000    78.000000           4.370000    78.000000
# 50%              4.000000    93.000000           5.755000    93.000000
# 75%             28.000000    97.000000           7.330000    97.000000
# max           2500.000000    99.000000          17.600000    99.000000
#
#           HIV/AIDS            GDP    Population   thinness  1-19 years  \
# count  2938.000000    2938.000000  2.938000e+03            2938.000000
# mean      1.742103    6611.523863  1.023085e+07               4.821886
# std       5.077785   13296.603449  5.402242e+07               4.397621
# min       0.100000       1.681350  3.400000e+01               0.100000
# 25%       0.100000     580.486996  4.189172e+05               1.600000
# 50%       0.100000    1766.947595  1.386542e+06               3.300000
# 75%       0.800000    4779.405190  4.584371e+06               7.100000
# max      50.600000  119172.741800  1.293859e+09              27.700000
#
#         thinness 5-9 years  Income composition of resources    Schooling  \
# count          2938.000000                      2938.000000  2938.000000
# mean              4.852144                         0.630362    12.009837
# std               4.485854                         0.205140     3.265139
# min               0.100000                         0.000000     0.000000
# 25%               1.600000                         0.504250    10.300000
# 50%               3.300000                         0.677000    12.300000
# 75%               7.200000                         0.772000    14.100000
# max              28.600000                         0.948000    20.700000
#
#        Life expectancy
# count      2938.000000
# mean         69.234717
# std           9.509115
# min          36.300000
# 25%          63.200000
# 50%          72.100000
# 75%          75.600000
# max          89.000000

# %%
#To create a predictive model, knowing from which country data comes can be confusing and it is not a column we can generalize over. 
#We want to learn a general pattern for all the countries, and not only those dependent on specific countries.

expectancy = expectancy.drop(columns = ["Country"])
expectancy.head()
# Out:
#    Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  2015  Developing            263.0             62     0.01
# 1  2014  Developing            271.0             64     0.01
# 2  2013  Developing            268.0             66     0.01
# 3  2012  Developing            272.0             69     0.01
# 4  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    ...  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0  ...               8.16         65.0        0.1  584.259210  33736494.0
# 1  ...               8.18         62.0        0.1  612.696514    327582.0
# 2  ...               8.13         64.0        0.1  631.744976  31731688.0
# 3  ...               8.52         67.0        0.1  669.959000   3696958.0
# 4  ...               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling  Life expectancy
# 0                            0.479       10.1             65.0
# 1                            0.476       10.0             59.9
# 2                            0.470        9.9             59.9
# 3                            0.463        9.8             59.5
# 4                            0.454        9.5             59.2
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Splitting data into labels and features.

# %%
#Selecting last column.
labels = expectancy.iloc[:,-1]
print(labels.head())

#Selecting all columns excluding the last one.
features = expectancy.iloc[:, 0: -1]
print(features.head())
# Out:
# 0    65.0
# 1    59.9
# 2    59.9
# 3    59.5
# 4    59.2
# Name: Life expectancy, dtype: float64
#    Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  2015  Developing            263.0             62     0.01
# 1  2014  Developing            271.0             64     0.01
# 2  2013  Developing            268.0             66     0.01
# 3  2012  Developing            272.0             69     0.01
# 4  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %% [markdown]
# ### One-hot-encoding of categorical data.

# %%
features = pd.get_dummies(features)
print(features)
# Out:
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0     2015            263.0             62     0.01               71.279624
# 1     2014            271.0             64     0.01               73.523582
# 2     2013            268.0             66     0.01               73.219243
# 3     2012            272.0             69     0.01               78.184215
# 4     2011            275.0             71     0.01                7.097109
# ...    ...              ...            ...      ...                     ...
# 2933  2004            723.0             27     4.36                0.000000
# 2934  2003            715.0             26     4.06                0.000000
# 2935  2002             73.0             25     4.43                0.000000
# 2936  2001            686.0             25     1.72                0.000000
# 2937  2000            665.0             24     1.68                0.000000
#
#       Hepatitis B  Measles    BMI   under-five deaths   Polio  ...  \
# 0            65.0      1154   19.1                  83    6.0  ...
# 1            62.0       492   18.6                  86   58.0  ...
# 2            64.0       430   18.1                  89   62.0  ...
# 3            67.0      2787   17.6                  93   67.0  ...
# 4            68.0      3013   17.2                  97   68.0  ...
# ...           ...       ...    ...                 ...    ...  ...
# 2933         68.0        31   27.1                  42   67.0  ...
# 2934          7.0       998   26.7                  41    7.0  ...
# 2935         73.0       304   26.3                  40   73.0  ...
# 2936         76.0       529   25.9                  39   76.0  ...
# 2937         79.0      1483   25.5                  39   78.0  ...
#
#       Diphtheria    HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0            65.0        0.1  584.259210  33736494.0                   17.2
# 1            62.0        0.1  612.696514    327582.0                   17.5
# 2            64.0        0.1  631.744976  31731688.0                   17.7
# 3            67.0        0.1  669.959000   3696958.0                   17.9
# 4            68.0        0.1   63.537231   2978599.0                   18.2
# ...           ...        ...         ...         ...                    ...
# 2933         65.0       33.6  454.366654  12777511.0                    9.4
# 2934         68.0       36.7  453.351155  12633897.0                    9.8
# 2935         71.0       39.8   57.348340    125525.0                    1.2
# 2936         75.0       42.1  548.587312  12366165.0                    1.6
# 2937         78.0       43.5  547.358879  12222251.0                   11.0
#
#        thinness 5-9 years  Income composition of resources  Schooling  \
# 0                    17.3                            0.479       10.1
# 1                    17.5                            0.476       10.0
# 2                    17.7                            0.470        9.9
# 3                    18.0                            0.463        9.8
# 4                    18.2                            0.454        9.5
# ...                   ...                              ...        ...
# 2933                  9.4                            0.407        9.2
# 2934                  9.9                            0.418        9.5
# 2935                  1.3                            0.427       10.0
# 2936                  1.7                            0.427        9.8
# 2937                 11.2                            0.434        9.8
#
#       Status_Developed  Status_Developing
# 0                    0                  1
# 1                    0                  1
# 2                    0                  1
# 3                    0                  1
# 4                    0                  1
# ...                ...                ...
# 2933                 0                  1
# 2934                 0                  1
# 2935                 0                  1
# 2936                 0                  1
# 2937                 0                  1
#
# [2938 rows x 21 columns]

# %% [markdown]
# ### Train-test split

# %%
feat_train, feat_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.3, random_state = 42)

print(feat_train.head())
print(labels_train)
print(labels_test)
# Out:
#       Year  Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1641  2008             64.0              0     7.14             2655.573684
# 618   2005            394.0              8     2.03                0.000000
# 406   2009            283.0             44     4.55               81.143047
# 1094  2011            289.0              4     3.57               40.453674
# 1788  2007            217.0             58     0.26                0.530573
#
#       Hepatitis B  Measles    BMI   under-five deaths   Polio  ...  \
# 1641         86.0         1   66.6                   0   72.0  ...
# 618          92.0       146   21.7                  13   62.0  ...
# 406          92.0     54118   16.1                  77   91.0  ...
# 1094         86.0         0   23.7                   7   85.0  ...
# 1788         85.0      1088   17.6                  78   84.0  ...
#
#       Diphtheria    HIV/AIDS           GDP  Population   thinness  1-19 years  \
# 1641         72.0        0.1  21928.767000     49379.0                    0.7
# 618          62.0        5.9   1766.947595   1386542.0                    8.8
# 406          92.0        1.1    552.745552   1514199.0                    9.3
# 1094         86.0        5.7    692.699890   1596154.0                    7.8
# 1788         86.0        0.6     41.451000  49171586.0                   13.2
#
#        thinness 5-9 years  Income composition of resources  Schooling  \
# 1641                  0.7                            0.813       14.6
# 618                   8.5                            0.496        9.4
# 406                   8.8                            0.356        5.9
# 1094                  7.7                            0.410        9.0
# 1788                 13.5                            0.484        8.1
#
#       Status_Developed  Status_Developing
# 1641                 1                  0
# 618                  0                  1
# 406                  0                  1
# 1094                 0                  1
# 1788                 0                  1
#
# [5 rows x 21 columns]
# 1641    80.0
# 618     55.3
# 406     56.9
# 1094    57.1
# 1788    64.5
#         ...
# 1638    87.0
# 1095    56.7
# 1130    61.8
# 1294    79.9
# 860     59.4
# Name: Life expectancy, Length: 2056, dtype: float64
# 2546    73.7
# 650     75.9
# 1740    74.2
# 177     76.8
# 1377    51.9
#         ...
# 1241    69.3
# 1456    69.9
# 123     86.0
# 2509    81.7
# 1728    64.0
# Name: Life expectancy, Length: 882, dtype: float64

# %% [markdown]
# ### Extracting float and integer variables and assigning them to variable with columns. It is required for ColumnTransformer.

# %%
num_feats = features.select_dtypes(include = ['float64', 'int64'])
num_cols = num_feats.columns

print(num_cols)
# Out:
# Index(['Year', 'Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ### Standarization

# %%
#Definig ColumnTransformer model 
ct = ColumnTransformer([('only_numeric', StandardScaler(), num_cols)], remainder = 'passthrough')

#Fitting and transforming trainning data in the model.
feat_train_scaled = ct.fit_transform(feat_train)
feat_test_scaled = ct.transform(feat_test)

print(feat_train_scaled, feat_test_scaled)
# Out:
# [[ 0.09628979 -0.81092833 -0.25772413 ...  0.78649403  1.
#    0.        ]
#  [-0.55350825  1.87482792 -0.18585883 ... -0.82511401  0.
#    1.        ]
#  [ 0.31288913  0.97143718  0.13753501 ... -1.9098502   0.
#    1.        ]
#  ...
#  [-0.12030956  0.83308004 -0.10501037 ... -1.13503864  0.
#    1.        ]
#  [-0.98670694 -0.74581909 -0.23975781 ...  1.03443373  1.
#    0.        ]
#  [-0.55350825 -1.05508799 -0.19484199 ... -2.06481251  0.
#    1.        ]] [[-0.3369089  -0.33074767 -0.18585883 ... -0.20526477  0.
#    1.        ]
#  [-0.3369089  -0.41213422 -0.25772413 ...  0.56954679  1.
#    0.        ]
#  [-0.12030956 -0.31447036 -0.25772413 ...  0.47656941  0.
#    1.        ]
#  ...
#  [-0.77010759 -0.77023506 -0.24874097 ...  2.67703424  1.
#    0.        ]
#  [ 0.74608782 -0.85976026 -0.25772413 ...  1.2203885   1.
#    0.        ]
#  [-0.98670694  0.87377332 -0.23975781 ... -0.48419693  0.
#    1.        ]]

# %% [markdown]
# ### Building the model
#
# Here, we are implementing model with one hidden layer with 128 neurons, ReLu as activation function and adam optimalizer.

# %%
#Implemening sequential model
model = Sequential()
#Defining input with shape adjusted to features.
input = InputLayer(input_shape = (features.shape[1]))
#Adding input layer
model.add(input)
#Adding hidden layer
model.add(Dense(128, activation = 'relu'))
#Adding output layer
model.add(Dense(1))
print(model)
# Out:
# <keras.engine.sequential.Sequential object at 0x0000023C565BEEE0>

# %%
#Defininig optimizer.
opt = Adam(learning_rate = 0.01)
print(opt)
# Out:
# <keras.optimizers.optimizer_v2.adam.Adam object at 0x0000023C565BE220>

# %%
#Model compilation.
model.compile(loss = 'mse', metrics = ['mae'], optimizer = opt)

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2816
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2,945
# Trainable params: 2,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Fitting and evaluating the model.

# %%
#For now, I'm struggling with "ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float)."
#Fitting the model.
model.fit(feat_train_scaled, labels_train, epochs = 40, batch_size = 1, verbose = 1)

#Evaluating model's metrics and loss function.
res_mse, res_mae = model.evaluate(feat_test_scaled, labels_test)

print(res_mse, res_mae)
# Out:
# Epoch 1/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 24.0580 - mae: 3.3417
# Epoch 2/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 11.5645 - mae: 2.4541
# Epoch 3/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 11.1311 - mae: 2.2756
# Epoch 4/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 9.1661 - mae: 2.1824
# Epoch 5/40
# 2056/2056 [==============================] - 3s 2ms/step - loss: 10.3321 - mae: 2.1775
# Epoch 6/40
# 2056/2056 [==============================] - 3s 2ms/step - loss: 8.9709 - mae: 2.0994
# Epoch 7/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 8.4136 - mae: 2.0230
# Epoch 8/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 7.3045 - mae: 1.9498
# Epoch 9/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 7.9184 - mae: 2.0010
# Epoch 10/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.9898 - mae: 1.9120
# Epoch 11/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 8.8492 - mae: 1.9668
# Epoch 12/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.7286 - mae: 1.8745
# Epoch 13/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.9558 - mae: 1.9027
# Epoch 14/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 7.0374 - mae: 1.8976
# Epoch 15/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 7.1375 - mae: 1.9003
# Epoch 16/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.4627 - mae: 1.8297
# Epoch 17/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.5754 - mae: 1.8478
# Epoch 18/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.6737 - mae: 1.8762
# Epoch 19/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.5732 - mae: 1.8490
# Epoch 20/40
# 2056/2056 [==============================] - 5s 2ms/step - loss: 6.3045 - mae: 1.8157
# Epoch 21/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.3943 - mae: 1.8017
# Epoch 22/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.3466 - mae: 1.8256
# Epoch 23/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.3705 - mae: 1.8019
# Epoch 24/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.2019 - mae: 1.7888
# Epoch 25/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.1523 - mae: 1.7804
# Epoch 26/40
# 2056/2056 [==============================] - 3s 2ms/step - loss: 6.1056 - mae: 1.7611
# Epoch 27/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.8170 - mae: 1.7429
# Epoch 28/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.8538 - mae: 1.7571
# Epoch 29/40
# 2056/2056 [==============================] - 3s 2ms/step - loss: 6.1829 - mae: 1.8001
# Epoch 30/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.9314 - mae: 1.7268
# Epoch 31/40
# 2056/2056 [==============================] - 3s 2ms/step - loss: 5.9185 - mae: 1.7521
# Epoch 32/40
# 2056/2056 [==============================] - 5s 2ms/step - loss: 6.0399 - mae: 1.7484
# Epoch 33/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.8492 - mae: 1.7439
# Epoch 34/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.9384 - mae: 1.7470
# Epoch 35/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.8932 - mae: 1.7568
# Epoch 36/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.9851 - mae: 1.7728
# Epoch 37/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 6.3653 - mae: 1.8082
# Epoch 38/40
# 2056/2056 [==============================] - 3s 2ms/step - loss: 5.8358 - mae: 1.7522
# Epoch 39/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.7558 - mae: 1.7571
# Epoch 40/40
# 2056/2056 [==============================] - 4s 2ms/step - loss: 5.7772 - mae: 1.7443
# 28/28 [==============================] - 0s 2ms/step - loss: 6.9663 - mae: 1.8561
# 6.966291904449463 1.8560799360275269
